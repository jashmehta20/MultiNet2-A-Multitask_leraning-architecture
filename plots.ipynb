# %%
PATH = r"C:\Users\neetm\Desktop\DL\project\mtan\results\vanila_multinet_resnet_fcn"
FILE_NAME = r"C:\Users\neetm\Desktop\DL\project\results\vanila_multine_fcn8_resnet\run 4 28.txt"
format = 'LOSS FORMAT: SEMANTIC_LOSS MEAN_IOU PIX_ACC | DEPTH_LOSS ABS_ERR REL_ERR | NORMAL_LOSS MEAN MED <11.25 <22.5 <30'
train_semantic_loss = []
train_mean_iou = []
train_pix_acc = []

train_depth_loss = []
train_depth_abs_err = []
train_depth_rel_err = []

train_normal_loss = []
train_mean = []
train_med = []

test_semantic_loss = []
test_mean_iou = []
test_pix_acc = []

test_depth_loss = []
test_depth_abs_err = []
test_depth_rel_err = []

test_normal_loss = []
test_mean = []
test_med = []

with open(FILE_NAME, 'r') as f:
    lines = f.readlines()
    for line in lines:
        train_semantic_loss.append(float(line[21:27]))
        train_mean_iou.append(float(line[28:34]))
        train_pix_acc.append(float(line[35:41]))

        train_depth_loss.append(float(line[44:50]))
        train_depth_abs_err.append(float(line[51:57]))
        train_depth_rel_err.append(float(line[58:64]))

        train_normal_loss.append(float(line[67:73]))
        train_mean.append(float(line[74:81]))
        train_med.append(float(line[82:89]))

        test_semantic_loss.append(float(line[119:125]))
        test_mean_iou.append(float(line[126:132]))
        test_pix_acc.append(float(line[133:139]))

        test_depth_loss.append(float(line[142:148]))
        test_depth_abs_err.append(float(line[149:155]))
        test_depth_rel_err.append(float(line[156:162]))

        test_normal_loss.append(float(line[165:171]))
        test_mean.append(float(line[172:179]))
        test_med.append(float(line[180:187]))

import numpy as np
import matplotlib.pyplot as plt
from os.path import join as osp
metrics_list = ["train semantic loss",
        "train mean iou",
        "train pix acc",
        "train depth loss",
        "train depth abs err",
        "train depth rel err",
        "train normal loss",
        "train mean",
        "train med",

        "test semantic loss",
        "test mean iou",
        "test pix acc",
        "test depth loss",
        "test depth abs err",
        "test depth rel err",
        "test normal loss",
        "test mean",
        "test med"]

metrics_values_resnet = [train_semantic_loss,
        train_mean_iou,
        train_pix_acc,

        train_depth_loss,
        train_depth_abs_err,
        train_depth_rel_err,

        train_normal_loss,
        train_mean,
        train_med,

        test_semantic_loss,
        test_mean_iou,
        test_pix_acc,

        test_depth_loss,
        test_depth_abs_err,
        test_depth_rel_err,

        test_normal_loss,
        test_mean,
        test_med]

epochs = list(range(len(test_depth_abs_err)))

# for i in range(len(metrics_list)):
#     fig = plt.figure()
#     plt.plot(epochs, metrics_values[i])
#     plt.title(metrics_list[i])
#     plt.xlabel("epochs")
#     plt.ylabel(metrics_list[i])
#     plt.show()
#     fig.savefig(osp(PATH, metrics_list[i]), dpi=1000)

print(max(test_mean_iou), max(test_pix_acc), min(test_depth_abs_err), min(test_depth_rel_err), max(test_mean), max(test_med))
# Out:
# 0.5487 0.7648 0.4062 0.1697 37.9376 33.9444

# %%
PATH = r"C:\Users\neetm\Desktop\DL\project\mtan\results\vanila_multinet_resnet_fcn"
FILE_NAME = r"C:\Users\neetm\Desktop\DL\project\results\vanila_multinet\multinet run 4 28"
format = 'LOSS FORMAT: SEMANTIC_LOSS MEAN_IOU PIX_ACC | DEPTH_LOSS ABS_ERR REL_ERR | NORMAL_LOSS MEAN MED <11.25 <22.5 <30'
train_semantic_loss = []
train_mean_iou = []
train_pix_acc = []

train_depth_loss = []
train_depth_abs_err = []
train_depth_rel_err = []

train_normal_loss = []
train_mean = []
train_med = []

test_semantic_loss = []
test_mean_iou = []
test_pix_acc = []

test_depth_loss = []
test_depth_abs_err = []
test_depth_rel_err = []

test_normal_loss = []
test_mean = []
test_med = []

with open(FILE_NAME, 'r') as f:
    lines = f.readlines()
    for line in lines:
        train_semantic_loss.append(float(line[21:27]))
        train_mean_iou.append(float(line[28:34]))
        train_pix_acc.append(float(line[35:41]))

        train_depth_loss.append(float(line[44:50]))
        train_depth_abs_err.append(float(line[51:57]))
        train_depth_rel_err.append(float(line[58:64]))

        train_normal_loss.append(float(line[67:73]))
        train_mean.append(float(line[74:81]))
        train_med.append(float(line[82:89]))

        test_semantic_loss.append(float(line[119:125]))
        test_mean_iou.append(float(line[126:132]))
        test_pix_acc.append(float(line[133:139]))

        test_depth_loss.append(float(line[142:148]))
        test_depth_abs_err.append(float(line[149:155]))
        test_depth_rel_err.append(float(line[156:162]))

        test_normal_loss.append(float(line[165:171]))
        test_mean.append(float(line[172:179]))
        test_med.append(float(line[180:187]))

import numpy as np
import matplotlib.pyplot as plt
from os.path import join as osp
metrics_list = ["train semantic loss",
        "train mean iou",
        "train pix acc",
        "train depth loss",
        "train depth abs err",
        "train depth rel err",
        "train normal loss",
        "train mean",
        "train med",

        "test semantic loss",
        "test mean iou",
        "test pix acc",
        "test depth loss",
        "test depth abs err",
        "test depth rel err",
        "test normal loss",
        "test mean",
        "test med"]

metrics_values_vgg = [train_semantic_loss,
        train_mean_iou,
        train_pix_acc,

        train_depth_loss,
        train_depth_abs_err,
        train_depth_rel_err,

        train_normal_loss,
        train_mean,
        train_med,

        test_semantic_loss,
        test_mean_iou,
        test_pix_acc,

        test_depth_loss,
        test_depth_abs_err,
        test_depth_rel_err,

        test_normal_loss,
        test_mean,
        test_med]

epochs = list(range(len(test_depth_abs_err)))

# for i in range(len(metrics_list)):
#     fig = plt.figure()
#     plt.plot(epochs, metrics_values[i])
#     plt.title(metrics_list[i])
#     plt.xlabel("epochs")
#     plt.ylabel(metrics_list[i])
#     plt.show()
#     fig.savefig(osp(PATH, metrics_list[i]), dpi=1000)

print(max(test_mean_iou), max(test_pix_acc), min(test_depth_abs_err), min(test_depth_rel_err), max(test_mean), max(test_med))
# Out:
# 0.4833 0.7167 0.5102 0.2048 51.8259 45.1275

# %%
PATH = r"C:\Users\neetm\Desktop\DL\project\mtan\results\vanila_multinet_resnet_fcn"
FILE_NAME = r"C:\Users\neetm\Desktop\DL\project\results\mtan\run 27 4 mtan.txt"
format = 'LOSS FORMAT: SEMANTIC_LOSS MEAN_IOU PIX_ACC | DEPTH_LOSS ABS_ERR REL_ERR | NORMAL_LOSS MEAN MED <11.25 <22.5 <30'
train_semantic_loss = []
train_mean_iou = []
train_pix_acc = []

train_depth_loss = []
train_depth_abs_err = []
train_depth_rel_err = []

train_normal_loss = []
train_mean = []
train_med = []

test_semantic_loss = []
test_mean_iou = []
test_pix_acc = []

test_depth_loss = []
test_depth_abs_err = []
test_depth_rel_err = []

test_normal_loss = []
test_mean = []
test_med = []

with open(FILE_NAME, 'r') as f:
    lines = f.readlines()
    for line in lines:
        train_semantic_loss.append(float(line[21:27]))
        train_mean_iou.append(float(line[28:34]))
        train_pix_acc.append(float(line[35:41]))

        train_depth_loss.append(float(line[44:50]))
        train_depth_abs_err.append(float(line[51:57]))
        train_depth_rel_err.append(float(line[58:64]))

        train_normal_loss.append(float(line[67:73]))
        train_mean.append(float(line[74:81]))
        train_med.append(float(line[82:89]))

        test_semantic_loss.append(float(line[119:125]))
        test_mean_iou.append(float(line[126:132]))
        test_pix_acc.append(float(line[133:139]))

        test_depth_loss.append(float(line[142:148]))
        test_depth_abs_err.append(float(line[149:155]))
        test_depth_rel_err.append(float(line[156:162]))

        test_normal_loss.append(float(line[165:171]))
        test_mean.append(float(line[172:179]))
        test_med.append(float(line[180:187]))

import numpy as np
import matplotlib.pyplot as plt
from os.path import join as osp
metrics_list = ["train semantic loss",
        "train mean iou",
        "train pix acc",
        "train depth loss",
        "train depth abs err",
        "train depth rel err",
        "train normal loss",
        "train mean",
        "train med",

        "test semantic loss",
        "test mean iou",
        "test pix acc",
        "test depth loss",
        "test depth abs err",
        "test depth rel err",
        "test normal loss",
        "test mean",
        "test med"]

metrics_values_mtan = [train_semantic_loss,
        train_mean_iou,
        train_pix_acc,

        train_depth_loss,
        train_depth_abs_err,
        train_depth_rel_err,

        train_normal_loss,
        train_mean,
        train_med,

        test_semantic_loss,
        test_mean_iou,
        test_pix_acc,

        test_depth_loss,
        test_depth_abs_err,
        test_depth_rel_err,

        test_normal_loss,
        test_mean,
        test_med]

epochs = list(range(len(test_depth_abs_err)))

# for i in range(len(metrics_list)):
#     fig = plt.figure()
#     plt.plot(epochs, metrics_values[i])
#     plt.title(metrics_list[i])
#     plt.xlabel("epochs")
#     plt.ylabel(metrics_list[i])
#     plt.show()
#     fig.savefig(osp(PATH, metrics_list[i]), dpi=1000)

print(max(test_mean_iou), max(test_pix_acc), min(test_depth_abs_err), min(test_depth_rel_err), max(test_mean), max(test_med))
# Out:
# 0.3763 0.6432 0.5427 0.2177 44.6274 42.6597

# %%
# metrics_values_resnet = metrics_values_resnet[0:113]
# metrics_values_vgg = metrics_values_vgg[0:113]
# metrics_values_mtan = metrics_values_mtan[0:113]
# print(len())
PATH = r"C:\Users\neetm\Desktop\DL\project\results"
epochs = list(range(113))

for i in range(len(metrics_list)):
    fig = plt.figure()
    plt.plot(epochs, metrics_values_mtan[i][0:113] )
    plt.plot(epochs, metrics_values_vgg[i][0:113])
    plt.plot(epochs, metrics_values_resnet[i][0:113] )
    plt.title(metrics_list[i])
    plt.legend(['MTAN', "MultiNet-2 VGG16", "MultiNet-2 ResNet101"])
    plt.xlabel("epochs")
    plt.ylabel(metrics_list[i])
    plt.show()
    fig.savefig(osp(PATH, metrics_list[i]+".png"), dpi=1000)

# %% [markdown]
# Semantic

# %%
PATH = r"C:\Users\neetm\Desktop\DL\project\mtan\results\segment_vgg"
FILE_NAME = r"C:\Users\neetm\Desktop\DL\project\mtan\results\fcn_semantic\run 4 27 fcn semantic.txt"
format = 'LOSS FORMAT: SEMANTIC_LOSS MEAN_IOU PIX_ACC | DEPTH_LOSS ABS_ERR REL_ERR | NORMAL_LOSS MEAN MED <11.25 <22.5 <30'
train_semantic_loss = []
train_mean_iou = []
train_pix_acc = []


test_semantic_loss = []
test_mean_iou = []
test_pix_acc = []


with open(FILE_NAME, 'r') as f:
    lines = f.readlines()
    for line in lines:
        train_semantic_loss.append(float(line[21:27]))
        train_mean_iou.append(float(line[28:34]))
        train_pix_acc.append(float(line[35:41]))

        test_semantic_loss.append(float(line[49:55]))
        test_mean_iou.append(float(line[56:62]))
        test_pix_acc.append(float(line[63:69]))

import numpy as np
import matplotlib.pyplot as plt
from os.path import join as osp
metrics_list = ["train semantic loss",
        "train mean iou",
        "train pix acc",


        "test semantic loss",
        "test mean iou",
        "test pix acc"]

metrics_values = [train_semantic_loss,
        train_mean_iou,
        train_pix_acc,


        test_semantic_loss,
        test_mean_iou,
        test_pix_acc]

epochs = list(range(len(lines)))

# for i in range(len(metrics_list)):
#     fig = plt.figure()
#     plt.plot(epochs, metrics_values[i])
#     plt.title(metrics_list[i])
#     plt.xlabel("epochs")
#     plt.ylabel(metrics_list[i])
#     plt.show()
#     fig.savefig(osp(PATH, metrics_list[i]), dpi=1000)
# print(test_mean_iou)
print(max(test_mean_iou))
print(max(test_pix_acc))

# %% [markdown]
# DEPTH

# %%
PATH = r"C:\Users\neetm\Desktop\DL\project\mtan\results\fcn_depth"
FILE_NAME = r"C:\Users\neetm\Desktop\DL\project\mtan\results\fcn_depth\run 4 27 depth fcn single"
format = 'LOSS FORMAT: SEMANTIC_LOSS MEAN_IOU PIX_ACC | DEPTH_LOSS ABS_ERR REL_ERR | NORMAL_LOSS MEAN MED <11.25 <22.5 <30'

train_depth_loss = []
train_depth_abs_err = []
train_depth_rel_err = []



test_depth_loss = []
test_depth_abs_err = []
test_depth_rel_err = []


with open(FILE_NAME, 'r') as f:
    lines = f.readlines()
    for line in lines:

        train_depth_loss.append(float(line[21:27]))
        train_depth_abs_err.append(float(line[28:34]))
        train_depth_rel_err.append(float(line[35:41]))


        test_depth_loss.append(float(line[49:55]))
        test_depth_abs_err.append(float(line[56:62]))
        test_depth_rel_err.append(float(line[63:69]))


import numpy as np
import matplotlib.pyplot as plt
from os.path import join as osp
metrics_list = ["train depth loss",
        "train depth abs err",
        "train depth rel err",

        "test depth loss",
        "test depth abs err",
        "test depth rel err"]

metrics_values = [
        train_depth_loss,
        train_depth_abs_err,
        train_depth_rel_err,


        test_depth_loss,
        test_depth_abs_err,
        test_depth_rel_err]

epochs = list(range(len(test_depth_abs_err)))

# for i in range(len(metrics_list)):
#     fig = plt.figure()
#     plt.plot(epochs, metrics_values[i])
#     plt.title(metrics_list[i])
#     plt.xlabel("epochs")
#     plt.ylabel(metrics_list[i])
#     plt.show()
#     fig.savefig(osp(PATH, metrics_list[i]), dpi=1000)

print(min(test_depth_abs_err), min(test_depth_rel_err))

test_depth_abs_err.sort()
test_depth_abs_err

# %% [markdown]
# NORMAL

# %%
PATH = r"C:\Users\neetm\Desktop\DL\project\results\fcn_normal"
FILE_NAME = r"C:\Users\neetm\Desktop\DL\project\results\fcn_normal\run 5 2.txt"
format = 'LOSS FORMAT: SEMANTIC_LOSS MEAN_IOU PIX_ACC | DEPTH_LOSS ABS_ERR REL_ERR | NORMAL_LOSS MEAN MED <11.25 <22.5 <30'


train_normal_loss = []
train_mean = []
train_med = []

test_normal_loss = []
test_mean = []
test_med = []

with open(FILE_NAME, 'r') as f:
    lines = f.readlines()
    for line in lines:

        train_normal_loss.append(float(line[21:27]))
        train_mean.append(float(line[28:35]))
        train_med.append(float(line[36:43]))

        test_normal_loss.append(float(line[71:77]))
        test_mean.append(float(line[78:85]))
        test_med.append(float(line[86:93]))

import numpy as np
import matplotlib.pyplot as plt
from os.path import join as osp
metrics_list = [
        "train normal loss",
        "train mean",
        "train med",

        "test normal loss",
        "test mean",
        "test med"]

metrics_values = [
        train_normal_loss,
        train_mean,
        train_med,

        test_normal_loss,
        test_mean,
        test_med]

epochs = list(range(len(lines)))

for i in range(len(metrics_list)):
    fig = plt.figure()
    plt.plot(epochs, metrics_values[i])
    plt.title(metrics_list[i])
    plt.xlabel("epochs")
    plt.ylabel(metrics_list[i])
    plt.show()
    fig.savefig(osp(PATH, metrics_list[i]), dpi=1000)

print(min(test_mean), min(test_med))
# Out:
# 46.8664 44.455
